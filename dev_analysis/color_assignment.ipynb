# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans

# %%
image_path = "../output_videos/cropped_img.jpg"
image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# Out:
# [ WARN:0@6.538] global loadsave.cpp:241 findDecoder imread_('../output_videos/cropped_img.jpg'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[2], line 3
#       1 image_path = "../output_videos/cropped_img.jpg"
#       2 image = cv2.imread(image_path)
# ----> 3 image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#
# error: OpenCV(4.10.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
plt.imshow(image)
plt.show()

# %%
top_half_image = image[0: int(image.shape[0]/2),:]
image_2d = top_half_image.reshape(-1, 3)
kmeans = KMeans(n_clusters = 2, random_state=0).fit(image_2d)
labels = kmeans.labels_
clustered_image = labels.reshape(top_half_image.shape[0], top_half_image.shape[1])
plt.imshow(clustered_image)
plt.show()

# %%
corner_clusters = [clustered_image[0,0], clustered_image[0, -1], clustered_image[-1, 0], clustered_image[-1, -1]]
non_players_colors = max(set(corner_clusters), key = corner_clusters.count)
player_cluster = 1 - non_players_colors
print(player_cluster)
# Out:
# 1

# %%
kmeans.cluster_centers_[player_cluster]
# Out:
# array([241.188, 241.924, 226.42 ])
